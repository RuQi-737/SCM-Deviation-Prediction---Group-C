# %% [markdown]
# ## 1. Libraries
# The standard data-science stack. `display` renders DataFrames nicely inside the loops further down.

# %%
import sys
import re
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display

# Identify the current working directory of the Jupyter kernel
current_dir = Path.cwd()
# Dynamically resolve the project root
# Target the parent directory if currently in 'notebooks', otherwise maintain current directory
project_root = current_dir.parent if current_dir.name == "notebooks" else current_dir
# Append the resolved root to the system path to enable modular imports
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))
from src.preprocessing import load_procurement, perform_structural_cleansing, data_cleansing_2, audit_column_formats, data_clean_3,analyze_order_complexity, analyze_quantity_delay_correlation, visualize_comprehensive_correlations, get_supplier_metrics, analyze_temporal_trends

# %% [markdown]
# ## 2. Predefined functions
# Just small helpers, one per cell. For everything else we use built-in pandas
# (`.head()`, `.dtypes`, `.isna()`, `crosstab`) instead of custom code — easier to read and to defend in the report.

# %% [markdown]
# **2.1 `load_procurement`** — reads one semicolon-separated CSV and turns the date columns into
# real datetimes. `errors="coerce"` converts unparseable values to `NaT` instead of crashing.
# The two files don't share all columns, so we only touch the dates that actually exist.

# %% [markdown]
# ## 3. Load Data
# Set `DATA_DIR` to the folder with your CSVs, then load both companies and attach the derived fields.

# %%
DATA_DIR = Path('..') / 'data/raw' 
FILES = {
    "A": "Procurement_Data_Company_A_anonymized.csv",
    "B": "Procurement_Data_Company_B_anonymized.csv",
}

data = {}
for key, fname in FILES.items():
    data[key] = load_procurement(DATA_DIR / fname)
    print(f"Company {key}: {data[key].shape[0]} rows, {data[key].shape[1]} columns")
# Out:
# Company A: 9194 rows, 11 columns
# Company B: 18078 rows, 12 columns

# %% [markdown]
# ## 4. What does the data look like? - Step 1 of data cleansing
# First a glance at the raw rows, then the feature types and duplicates missing values. As discussed in the Lecture aim is imidiatly to improve data quality.

# %%
for name, df in data.items():
    print(f"--- Company {name} ---")
    display(df.head(10))
# Out:
# --- Company A ---
#    Order Number  Order Position  Supplier                 Ordered Product  \
# 0         74682              11  41781068                       V-Flansch
# 1         74682              11  41781068                       V-Flansch
# 2         74682              11  41781068                       V-Flansch
# 3         74682              14  41781068                      WN-Flansch
# 4         74682              14  41781068                      WN-Flansch
# 5         74666               2  49689366              Kammprofildichtung
# 6         74666               4  49689366              Kammprofildichtung
# 7         74806               1  69934049                  Spiraldichtung
# 8         74585               1  61231028  Blech (EN 10029A;ASME VIII/1;E
# 9         74585               4  61231028  Blech (EN 10029A;ASME VIII/1;E
#
#    Product Article Number          End Product Planned Delivery Date  \
# 0                  3000.0                  NaN            2023-01-05
# 1                  3000.0                  NaN            2023-01-05
# 2                  3000.0                  NaN            2023-01-05
# 3                  3500.0                  NaN            2023-01-05
# 4                  3500.0                  NaN            2023-01-05
# 5                  6110.0  Mantel für EA-2901B            2023-01-04
# 6                  6110.0  Mantel für EA-2901A            2023-01-04
# 7                  6200.0    Reaktor C-[NUM] A            2023-01-30
# 8                  1000.0                  NaN            2023-01-13
# 9                  1000.0                  NaN            2023-01-13
#
#   Arrival Date  Ordered Quantity  Delivered Quantity Quality
# 0   2022-12-15               3.0                 3.0     3.1
# 1   2022-12-15               3.0                 3.0     3.1
# 2   2022-12-15               3.0                 3.0     3.1
# 3   2022-12-15               2.0                 2.0     3.1
# 4   2022-12-15               2.0                 2.0     3.1
# 5   2023-01-04               1.0                 1.0     NaN
# 6   2023-01-04               1.0                 1.0     NaN
# 7   2023-01-04               4.0                 4.0     NaN
# 8   2023-01-05               2.0                 2.0     3.1
# 9   2023-01-05               2.0                 2.0     3.2
# --- Company B ---
#    Order Number  Supplier Number  Supplier Product Article Number  \
# 0       6260783            70214  93118673            23101030601
# 1       6260784            70175  41446825            23100770000
# 2       6260785            72156  22740983            23101070000
# 3       6260786            72156  22740983            23101081101
# 4       6260786            72156  22740983            23101080001
# 5       6260786            72156  22740983            23101081101
# 6       6260786            72156  22740983            23101080001
# 7       6260786            72156  22740983                   9999
# 8       6260787            71389  23635582            29000190000
# 9       6260788            71416  10488377            22900710605
#
#                                 Ordered Product  \
# 0             Halteplatte für OPC-Schnittstelle
# 1           Gehäuse [CODE]/[NUM] [NUM], A [NUM]
# 2    Gehäuse kpl. [CODE] rf Z.Nr.:[CODE]-[CODE]
# 3  Deckel Steuereinsatz [CODE],[CODE].[NUM] kpl
# 4     Gehäuse kpl. [CODE] Z.Nr.:KR519052_[PART]
# 5  Deckel Steuereinsatz [CODE],[CODE].[NUM] kpl
# 6     Gehäuse kpl. [CODE] Z.Nr.:KR519052_[PART]
# 7                    Werkzzeugkosten (Änderung)
# 8               Linsenschraube [CODE] DIN [NUM]
# 9           Bestückte Platine [NUM] [NUM] [NUM]
#
#        Ordered Product - Supplement  Original Ordered Quantity  \
# 0              REOVIB [CODE] [CODE]                       14.0
# 1                  Alu-/Gussgehäuse                       50.0
# 2                             [NUM]                       30.0
# 3                       Z.Nr:[CODE]                      100.0
# 4                             [NUM]                      100.0
# 5                       Z.Nr:[CODE]                       40.0
# 6                             [NUM]                       40.0
# 7                               NaN                        0.0
# 8  Stahl verzinkt, mit Kreuzschlitz                    20000.0
# 9                             [NUM]                     1500.0
#
#   Original Desired Date Planned Delivery Date  Ordered Quantity Arrival Date  \
# 0            2023-05-01            2023-05-01              14.0   2023-05-23
# 1            2023-09-04            2023-09-04              50.0   2023-09-04
# 2            2023-08-21            2023-08-21              30.0   2023-08-24
# 3            2023-11-06            2023-11-06             100.0   2023-11-03
# 4            2023-11-06            2023-11-06             100.0   2023-11-03
# 5            2023-05-22            2023-05-22              40.0   2023-05-22
# 6            2023-04-24            2023-04-24              40.0   2023-05-09
# 7            2023-12-04            2023-12-04               0.0          NaT
# 8            2023-01-09            2023-01-09           20000.0   2023-01-12
# 9            2023-12-04            2023-12-04            1500.0   2023-12-01
#
#    Delivered Quantity
# 0                14.0
# 1                50.0
# 2                30.0
# 3               100.0
# 4               100.0
# 5                40.0
# 6                40.0
# 7                 NaN
# 8             20000.0
# 9              1000.0

# %% [markdown]
# **Data types, duplicates & missing values.** Note that `Order Number`, `Supplier` and
# `Product Article Number` are stored as numbers but are **identifiers** — categorical, not numeric.
# Used as an overview.

# %%
for name, df in data.items():
    print(f"===== Company {name} =====")
    print(df.dtypes, "\n")
    print("Missing values:")
    print(df.isna().sum(), "\n")
    print("Duplicate rows:")
    print(df.duplicated().sum(), "\n")


audit_column_formats(data, ['Ordered Quantity', 'Delivered Quantity'])
# Out:
# ===== Company A =====
# Order Number                       int64
# Order Position                     int64
# Supplier                           int64
# Ordered Product                      str
# Product Article Number           float64
# End Product                          str
# Planned Delivery Date     datetime64[us]
# Arrival Date              datetime64[us]
# Ordered Quantity                 float64
# Delivered Quantity               float64
# Quality                              str
# dtype: object
#
# Missing values:
# Order Number                 0
# Order Position               0
# Supplier                     0
# Ordered Product              2
# Product Article Number     544
# End Product               5974
# Planned Delivery Date        0
# Arrival Date              2893
# Ordered Quantity             0
# Delivered Quantity        2893
# Quality                   6118
# dtype: int64
#
# Duplicate rows:
# 1980
#
# ===== Company B =====
# Order Number                             int64
# Supplier Number                          int64
# Supplier                                 int64
# Product Article Number                     str
# Ordered Product                            str
# Ordered Product - Supplement               str
# Original Ordered Quantity              float64
# Original Desired Date           datetime64[us]
# Planned Delivery Date           datetime64[us]
# Ordered Quantity                       float64
# Arrival Date                    datetime64[us]
# Delivered Quantity                     float64
# dtype: object
#
# Missing values:
# Order Number                       0
# Supplier Number                    0
# Supplier                           0
# Product Article Number          1310
# Ordered Product                  991
# Ordered Product - Supplement    2771
# Original Ordered Quantity        851
# Original Desired Date            995
# Planned Delivery Date              4
# Ordered Quantity                   0
# Arrival Date                    2052
# Delivered Quantity              2052
# dtype: int64
#
# Duplicate rows:
# 142
#
# --- DATA FORMAT AUDIT REPORT ---
#
# Evaluating Company A:
#   Column: 'Ordered Quantity' | Total Valid Rows: 9194
#     - US/Standard Numeric (98.0):       9194
#     - European Numeric (1.600.800,00):  0
#     - Corrupt Text ('frog', '10 pcs'):  0
#   Column: 'Delivered Quantity' | Total Valid Rows: 6301
#     - US/Standard Numeric (98.0):       6301
#     - European Numeric (1.600.800,00):  4
#     - Corrupt Text ('frog', '10 pcs'):  0
#
# Evaluating Company B:
#   Column: 'Ordered Quantity' | Total Valid Rows: 18078
#     - US/Standard Numeric (98.0):       18078
#     - European Numeric (1.600.800,00):  10
#     - Corrupt Text ('frog', '10 pcs'):  0
#   Column: 'Delivered Quantity' | Total Valid Rows: 16026
#     - US/Standard Numeric (98.0):       16026
#     - European Numeric (1.600.800,00):  11
#     - Corrupt Text ('frog', '10 pcs'):  0

# %% [markdown]
# Infered for our data cleansing can be:
# 1. Dupplicates can be removed
# 2. Rows with missing values in arrival date and/or delivered quantity can be deleted
# 3. All data not conform with these data types can be removed and the load function can be adapted to conform to these data types
# 4. European data formats should be removed -> unrealistic high number such as 1.6B insulation rollls

# %%
data_clean_1 = perform_structural_cleansing(data)
# Out:
# Company A Cleansing: Removed 4719 invalid rows. Remaining: 4475
# Company B Cleansing: Removed 2175 invalid rows. Remaining: 15903

# %% [markdown]
# ## 5. How are delivery dates & quantities distributed?
# ### 5.1  Univariate Analysis

# %%
def plot_univariate_scatter(df_dict):
    """
    Iterates through a dictionary of DataFrames and generates univariate 
    scatter plots to identify absolute anomalies prior to feature engineering.
    """
    for key, df in df_dict.items():
        # Setup visualization grid (2 rows, 2 columns)
        fig, axes = plt.subplots(2, 2, figsize=(14, 10))
        fig.suptitle(f'Univariate Scatter Analysis: Company {key}', fontsize=14)

        # Plot 1: Ordered Quantity
        if 'Ordered Quantity' in df.columns:
            axes[0, 0].scatter(df.index, df['Ordered Quantity'], alpha=0.5, color='steelblue', marker='.')
            axes[0, 0].set_title('Ordered Quantity')
            axes[0, 0].set_ylabel('Quantity')
            axes[0, 0].set_xlabel('Row Index')

        # Plot 2: Delivered Quantity
        if 'Delivered Quantity' in df.columns:
            axes[0, 1].scatter(df.index, df['Delivered Quantity'], alpha=0.5, color='mediumseagreen', marker='.')
            axes[0, 1].set_title('Delivered Quantity')
            axes[0, 1].set_ylabel('Quantity')
            axes[0, 1].set_xlabel('Row Index')

        # Plot 3: Planned Delivery Date
        if 'Planned Delivery Date' in df.columns:
            axes[1, 0].scatter(df.index, df['Planned Delivery Date'], alpha=0.5, color='purple', marker='.')
            axes[1, 0].set_title('Planned Delivery Date')
            axes[1, 0].set_ylabel('Date')
            axes[1, 0].set_xlabel('Row Index')

        # Plot 4: Arrival Date
        if 'Arrival Date' in df.columns:
            axes[1, 1].scatter(df.index, df['Arrival Date'], alpha=0.5, color='darkorange', marker='.')
            axes[1, 1].set_title('Arrival Date')
            axes[1, 1].set_ylabel('Date')
            axes[1, 1].set_xlabel('Row Index')

        plt.tight_layout()
        plt.show()
    print("Company B - Absolute Max Ordered Quantity:", data_clean_1["B"]['Ordered Quantity'].max())
    print("Company B - Absolute Max Delivered Quantity:", data_clean_1["B"]['Delivered Quantity'].max())
plot_univariate_scatter(data_clean_1)
# Out:
# Company B - Absolute Max Ordered Quantity: 200000.0
# Company B - Absolute Max Delivered Quantity: 200000.0

# %% [markdown]
# Infered for our Data format for data cleansing can be:
# Company A
# 1. Check high Quantity of delivery and order -> 14000 must be wrong should be delted
# 2. Check for how many values are zero -> A lot delete
# 3. Univariat dates appear in order
# Company B
# 1. Check odd arrival dates and planned delivery dates in Company B -> delete anything which is not inbetween 2010 and today
# 2.Cap Quanitity at 100.000

# %%
data_clean_2 = data_cleansing_2(data_clean_1)
# Out:
# Company A Threshold Cleansing: Removed 16 anomalous rows. Remaining: 4459
# Company B Threshold Cleansing: Removed 1007 anomalous rows. Remaining: 14896

# %% [markdown]
# ### 5.2 Bivariate Analysis

# %%
# 4. Feature Engineering and Cleansing (Isolated Delta Analysis)


def plot_isolated_deltas(df_dict):
    """
    Generates a 2x2 grid of univariate scatter plots isolating the 
    Quantity Delta and Delivery Time Delta for Companies A and B.
    """
    fig, axes = plt.subplots(2, 2, figsize=(16, 12))
    fig.suptitle('Isolated Anomaly Detection: Fulfillment and Temporal Deltas', fontsize=16)

    for row_idx, (key, df) in enumerate(df_dict.items()):
        # Define required columns for mathematical delta calculations
        required_cols = ['Planned Delivery Date', 'Arrival Date', 'Ordered Quantity', 'Delivered Quantity']
        
        # Verify columns exist before computation
        if all(col in df.columns for col in required_cols):
            # Isolate valid rows to prevent NaN computation errors
            valid_data = df.dropna(subset=required_cols).copy()
            
            # 1. Calculate Quantity Delta (Positive = Under-delivery, Negative = Over-delivery)
            valid_data['Quantity_Delta'] = valid_data['Ordered Quantity'] - valid_data['Delivered Quantity']
            
            # 2. Calculate Delivery Time Delta (Positive = Late, Negative = Early)
            valid_data['Delivery_Delay_Days'] = (valid_data['Arrival Date'] - valid_data['Planned Delivery Date']).dt.days
            
            # Plot 1: Quantity Delta (Column 0)
            axes[row_idx, 0].scatter(valid_data.index, valid_data['Quantity_Delta'], 
                                     alpha=0.5, color='darkmagenta', marker='.')
            axes[row_idx, 0].set_title(f'Company {key}: Quantity Delta (Ordered - Delivered)')
            axes[row_idx, 0].set_ylabel('Quantity Difference')
            axes[row_idx, 0].set_xlabel('Row Index')
            axes[row_idx, 0].axhline(0, color='black', linestyle='-', linewidth=1.5, label='Exact Fulfillment')
            axes[row_idx, 0].legend()
            axes[row_idx, 0].grid(True, alpha=0.3)
            
            # Plot 2: Delivery Time Delta (Column 1)
            axes[row_idx, 1].scatter(valid_data.index, valid_data['Delivery_Delay_Days'], 
                                     alpha=0.5, color='crimson', marker='.')
            axes[row_idx, 1].set_title(f'Company {key}: Delivery Time Delta (Days)')
            axes[row_idx, 1].set_ylabel('Delay in Days')
            axes[row_idx, 1].set_xlabel('Row Index')
            axes[row_idx, 1].axhline(0, color='black', linestyle='-', linewidth=1.5, label='On Time')
            axes[row_idx, 1].legend()
            axes[row_idx, 1].grid(True, alpha=0.3)

    plt.tight_layout()
    plt.show()

# Execute the isolated delta analysis
plot_isolated_deltas(data_clean_2)

# %% [markdown]
# Infer from this for Data format:
# Company A:
# 1. Quantity: cap at 250
# 2. Delivery Delta seems good
#
# Company B:
# 1. Cap at 10.000 the Quantity
# 2. Cap Dates Delta at + 400. Check the -400 bc delivery of a part 1 year before planned is not usual.
#
# ### Early arrival analysis

# %%
# 1. Isolate Company B
df_b = data_clean_2["B"].copy()

# 2. Safely calculate the temporal delta (Arrival - Planned)
df_b['Delivery_Delay_Days'] = (df_b['Arrival Date'] - df_b['Planned Delivery Date']).dt.days

# 3. Filter for extreme early deliveries (smaller than -100 days)
extreme_early_b = df_b[df_b['Delivery_Delay_Days'] < -100]

# 4. Print the diagnostic summary
print("--- Company B: Extreme Early Delivery Audit ---")
print(f"Found {len(extreme_early_b)} orders arriving more than 100 days early.\n")

# 5. Display the critical columns to spot the typo
cols_to_view = ['Planned Delivery Date', 'Arrival Date', 'Delivery_Delay_Days', 'Ordered Quantity', 'Supplier Number', 'Original Desired Date']
if 'Order Number' in df_b.columns:
    cols_to_view.insert(0, 'Order Number')

# Show rows to visually inspect the years
display(extreme_early_b[cols_to_view])
# Out:
# --- Company B: Extreme Early Delivery Audit ---
# Found 154 orders arriving more than 100 days early.
#        Order Number Planned Delivery Date Arrival Date  Delivery_Delay_Days  \
# 236         6261472            2023-08-28   2023-04-27                 -123
# 237         6261472            2023-08-28   2023-04-27                 -123
# 238         6261472            2023-08-28   2023-04-27                 -123
# 245         6261474            2024-08-05   2024-03-28                 -130
# 368         6261147            2024-01-29   2023-09-08                 -143
# ...             ...                   ...          ...                  ...
# 14213      21131393            2024-01-01   2023-08-07                 -147
# 14214      21131393            2024-01-01   2023-08-07                 -147
# 14215      21131393            2024-01-01   2023-08-07                 -147
# 14216      21131393            2024-01-01   2023-08-07                 -147
# 16030      21131943            2024-11-13   2023-11-13                 -366
#
#        Ordered Quantity  Supplier Number Original Desired Date
# 236              1000.0            70245            2023-08-28
# 237               500.0            70245            2023-08-28
# 238               500.0            70245            2023-08-28
# 245              2250.0            71027            2024-08-05
# 368               254.0            70859            2024-01-29
# ...                 ...              ...                   ...
# 14213               1.0            71330            2024-01-01
# 14214               1.0            71330            2024-01-01
# 14215               1.0            71330            2024-01-01
# 14216               1.0            71330            2024-01-01
# 16030             600.0            70823            2024-11-13
#
# [154 rows x 7 columns]

# %% [markdown]
# From this can be inferred that there is no logic in a delivery that is 366 early. It could be inferred that the year of the deilivery has been input falsly. We therefore cap all earlly at -30 days dictated by basic business logic.

# %%
data_clean_3_dict = data_clean_3(data_clean_2)

# 2. Extract DataFrames for subsequent feature engineering
df_company_a_transformed = data_clean_3_dict['A']
df_company_b_transformed = data_clean_3_dict['B']
# Out:
# Company A: Capped extreme values. Total rows maintained: 4459
# Company B: Capped extreme values. Total rows maintained: 14896

# %% [markdown]
# ## 6. Transformation & Feature Engineering
# Let us first visulize the delay and quantity overall, then per supplier. After this the correlation between the 3.
# Also let us look into the connection of ordernumber and order position. The amount of position and the possible delay.

# %%
def visualize_order_consistency(df_dict, company_key):
    """
    KDD Phase: Exploratory Data Analysis
    Verifies if Order Numbers have consistent chronological dates 
    before aggregation is permitted.
    """
    df = df_dict[company_key].copy()
    
    if 'Order Number' not in df.columns:
        print(f"Company {company_key} lacks an 'Order Number' column for this grouping.")
        return

    # 1. Count unique dates per Order Number
    date_variance = df.groupby('Order Number').agg(
        Unique_Planned=('Planned Delivery Date', 'nunique'),
        Unique_Arrival=('Arrival Date', 'nunique')
    )
    
    # 2. Check for Split Deliveries (Orders with >1 unique arrival date)
    split_deliveries = date_variance[date_variance['Unique_Arrival'] > 1]
    
    print(f"--- Company {company_key} Order Consistency Audit ---")
    print(f"Total Unique Orders: {len(date_variance)}")
    print(f"Orders with Split Deliveries (>1 Arrival Date): {len(split_deliveries)}")
    
    # 3. Visualization
    fig, axes = plt.subplots(1, 2, figsize=(12, 4))
    
    date_variance['Unique_Planned'].value_counts().sort_index().plot(
        kind='bar', ax=axes[0], color='steelblue', edgecolor='black'
    )
    axes[0].set_title('Unique Planned Dates per Order')
    axes[0].set_xlabel('Number of Unique Dates')
    axes[0].set_ylabel('Order Count')
    
    date_variance['Unique_Arrival'].value_counts().sort_index().plot(
        kind='bar', ax=axes[1], color='darkorange', edgecolor='black'
    )
    axes[1].set_title('Unique Arrival Dates per Order')
    axes[1].set_xlabel('Number of Unique Dates')
    
    plt.tight_layout()
    plt.show()

# Run for Company B (and Company A if applicable)
for company in ['A', 'B']:
    visualize_order_consistency(data_clean_2, company)
# Out:
# --- Company A Order Consistency Audit ---
# Total Unique Orders: 943
# Orders with Split Deliveries (>1 Arrival Date): 181
# --- Company B Order Consistency Audit ---
# Total Unique Orders: 5923
# Orders with Split Deliveries (>1 Arrival Date): 1539

# %%
df_company_a_transformed, supp_a = get_supplier_metrics({'A': df_company_a_transformed}, 'A')
df_company_b_transformed, supp_b = get_supplier_metrics({'B': df_company_b_transformed}, 'B')


analyze_quantity_delay_correlation({'A': df_company_a_transformed}, 'A')
analyze_quantity_delay_correlation({'B': df_company_b_transformed}, 'B')


analyze_order_complexity({'A': df_company_a_transformed}, 'A')
analyze_order_complexity({'B': df_company_b_transformed}, 'B')

visualize_comprehensive_correlations({'A': df_company_a_transformed}, 'A')
visualize_comprehensive_correlations({'B': df_company_b_transformed}, 'B')
# Out:
# --- Company A: Top Suppliers by Late Percentage ---
#           Total_Orders  Mean_Delay  Median_Delay  Late_%  On_Time_%  Early_%
# Supplier
# 34298237            36       38.08          56.0   100.0        0.0      0.0
# 63187990            41       12.85          19.0   100.0        0.0      0.0
# 28731850            57       20.09          15.0    82.5        7.0     10.5
# 5827497             47        4.57           3.0    80.9        4.3     14.9
# 8106770            114        4.92           5.0    80.7       11.4      7.9
# 33311984            46        8.78           5.0    78.3        0.0     21.7
# 33444489           267       13.98          12.0    76.4        8.2     15.4
# 95570515           155       10.84           5.0    68.4       18.7     12.9
# 27164983            50        1.48           5.0    68.0        0.0     32.0
# 62658211           248        8.94          11.0    64.9       27.0      8.1
# --- Company B: Top Suppliers by Late Percentage ---
#           Total_Orders  Mean_Delay  Median_Delay  Late_%  On_Time_%  Early_%
# Supplier
# 54973100            32        1.38           1.0   100.0        0.0      0.0
# 83836376            74        2.93           2.0   100.0        0.0      0.0
# 25454551            47        3.89           2.0   100.0        0.0      0.0
# 97322756            31        3.35           3.0    96.8        3.2      0.0
# 499316              83        5.52           4.0    96.4        0.0      3.6
# 50833268            37       20.59          15.0    94.6        5.4      0.0
# 89096955           240       -1.67          10.0    93.8        0.4      5.8
# 19752449            31        2.16           2.0    93.5        3.2      3.2
# 65209445           130        4.99           5.0    93.1        2.3      4.6
# 22481727           131        1.90           2.0    93.1        0.0      6.9
# --- Company A: Correlation Matrix ---
#                      Ordered Quantity  Delivered Quantity  Delivery_Delay_Days
# Ordered Quantity                1.000               0.647               -0.056
# Delivered Quantity              0.647               1.000               -0.020
# Delivery_Delay_Days            -0.056              -0.020                1.000
# Insight: Order size has virtually no linear impact on lateness.
#
# --- Company B: Correlation Matrix ---
#                      Ordered Quantity  Delivered Quantity  Delivery_Delay_Days
# Ordered Quantity                1.000               0.676               -0.005
# Delivered Quantity              0.676               1.000               -0.007
# Delivery_Delay_Days            -0.005              -0.007                1.000
# Insight: Order size has virtually no linear impact on lateness.
#
# --- Company A: Order Complexity Analysis ---
# Average positions per order: 4.73
# Correlation (Positions vs. Max Delay): 0.174
# --- Company B: Order Complexity Analysis ---
# Average positions per order: 2.51
# Correlation (Positions vs. Max Delay): 0.086
# ========== Company A: Multivariate Visualization ==========
# ========== Company B: Multivariate Visualization ==========

# %% [markdown]
# ### TEMPORAL ANALYSIS

# %%
analyze_temporal_trends({'A': df_company_a_transformed}, 'A')
analyze_temporal_trends({'B': df_company_b_transformed}, 'B')
# Out:
# ========== Company A: Temporal & Seasonal Context ==========
# ========== Company B: Temporal & Seasonal Context ==========

# %%
# Combine your final DataFrames back into a dictionary format for the function
final_data = {
    'A': df_company_a_transformed,
    'B': df_company_b_transformed
}

# %% [markdown]
# ## 7. Feature Engineering
# Transformation of Company Data for a and b

# %% [markdown]
# ### 7.1 Company A

# %%
df_company_a_transformed.head()
# Out:
#    Order Number  Order Position  Supplier     Ordered Product  \
# 0         74682              11  41781068           V-Flansch
# 3         74682              14  41781068          WN-Flansch
# 5         74666               2  49689366  Kammprofildichtung
# 6         74666               4  49689366  Kammprofildichtung
# 7         74806               1  69934049      Spiraldichtung
#
#    Product Article Number          End Product Planned Delivery Date  \
# 0                  3000.0                  NaN            2023-01-05
# 3                  3500.0                  NaN            2023-01-05
# 5                  6110.0  Mantel für EA-2901B            2023-01-04
# 6                  6110.0  Mantel für EA-2901A            2023-01-04
# 7                  6200.0    Reaktor C-[NUM] A            2023-01-30
#
#   Arrival Date  Ordered Quantity  Delivered Quantity Quality  \
# 0   2022-12-15               3.0                 3.0     3.1
# 3   2022-12-15               2.0                 2.0     3.1
# 5   2023-01-04               1.0                 1.0     NaN
# 6   2023-01-04               1.0                 1.0     NaN
# 7   2023-01-04               4.0                 4.0     NaN
#
#    Delivery_Delay_Days   Status
# 0                  -21    early
# 3                  -21    early
# 5                    0  on_time
# 6                    0  on_time
# 7                  -26    early

# %%
df_company_a_transformed.dtypes
# Out:
# Order Number                       int64
# Order Position                     int64
# Supplier                           int64
# Ordered Product                      str
# Product Article Number           float64
# End Product                          str
# Planned Delivery Date     datetime64[us]
# Arrival Date              datetime64[us]
# Ordered Quantity                 float64
# Delivered Quantity               float64
# Quality                              str
# Delivery_Delay_Days                int64
# Status                               str
# dtype: object

# %%
import sys
sys.path.append('../src')

# %%
from FeatureEngineering import create_features_company_a, create_features_company_b, create_date_encoded_features

# %%
# Company A: Feature-DataFrame
df_company_a_features = create_features_company_a(df_company_a_transformed)
print("Shape:", df_company_a_features.shape)
df_company_a_features.head()
# Out:
# Shape: (4459, 14)
#   Unique Order Identifier  Order Complexity  Supplier  \
# 0                74682-11                17  41781068
# 3                74682-14                17  41781068
# 5                 74666-2                 7  49689366
# 6                 74666-4                 7  49689366
# 7                 74806-1                 1  69934049
#
#   Unique Product Identifier Planned Delivery Date Arrival Date  \
# 0                      3000            2023-01-05   2022-12-15
# 3                      3500            2023-01-05   2022-12-15
# 5                      6110            2023-01-04   2023-01-04
# 6                      6110            2023-01-04   2023-01-04
# 7                      6200            2023-01-30   2023-01-04
#
#    Delivery Delay Delivery Status  Ordered Quantity  Delivered Quantity  \
# 0             -21       too early               3.0                 3.0
# 3             -21       too early               2.0                 2.0
# 5               0         on time               1.0                 1.0
# 6               0         on time               1.0                 1.0
# 7             -26       too early               4.0                 4.0
#
#    Delivery_Delay_Days   Status  Quantity Difference Quantity Status
# 0                  -21    early                  0.0           exact
# 3                  -21    early                  0.0           exact
# 5                    0  on_time                  0.0           exact
# 6                    0  on_time                  0.0           exact
# 7                  -26    early                  0.0           exact

# %%
df_company_a_features.dtypes
# Out:
# Unique Order Identifier                 str
# Order Complexity                      int64
# Supplier                              int64
# Unique Product Identifier               str
# Planned Delivery Date        datetime64[us]
# Arrival Date                 datetime64[us]
# Delivery Delay                        int64
# Delivery Status                         str
# Ordered Quantity                    float64
# Delivered Quantity                  float64
# Delivery_Delay_Days                   int64
# Status                                  str
# Quantity Difference                 float64
# Quantity Status                         str
# dtype: object

# %% [markdown]
# Encoding for e.g. Supplier Values in Categories as Models would otherwise suggest this as numbers to make regression tasks

# %%
# Copy into new encoded dataframe
df_company_a_encoded = create_date_encoded_features(df_company_a_features)

df_company_a_encoded.head()
# Out:
#   Unique Order Identifier  Order Complexity  Supplier  \
# 0                74682-11                17  41781068
# 3                74682-14                17  41781068
# 5                 74666-2                 7  49689366
# 6                 74666-4                 7  49689366
# 7                 74806-1                 1  69934049
#
#   Unique Product Identifier  Planned Year  Planned Month  Planned Quarter  \
# 0                      3000          2023              1                1
# 3                      3500          2023              1                1
# 5                      6110          2023              1                1
# 6                      6110          2023              1                1
# 7                      6200          2023              1                1
#
#    Planned Day  Planned Weekday  Arrival Year  ...  Arrival Day  \
# 0            5                3          2022  ...           15
# 3            5                3          2022  ...           15
# 5            4                2          2023  ...            4
# 6            4                2          2023  ...            4
# 7           30                0          2023  ...            4
#
#    Arrival Weekday  Delivery Delay  Delivery Status  Ordered Quantity  \
# 0                3             -21        too early               3.0
# 3                3             -21        too early               2.0
# 5                2               0          on time               1.0
# 6                2               0          on time               1.0
# 7                2             -26        too early               4.0
#
#   Delivered Quantity  Delivery_Delay_Days   Status  Quantity Difference  \
# 0                3.0                  -21    early                  0.0
# 3                2.0                  -21    early                  0.0
# 5                1.0                    0  on_time                  0.0
# 6                1.0                    0  on_time                  0.0
# 7                4.0                  -26    early                  0.0
#
#   Quantity Status
# 0           exact
# 3           exact
# 5           exact
# 6           exact
# 7           exact
#
# [5 rows x 22 columns]

# %%
df_company_a_encoded.to_csv('company_a_ML.csv', index=False)

# %% [markdown]
# ### 7.2 Company B

# %%
df_company_b_transformed.head()
# Out:
#    Order Number  Supplier Number  Supplier Product Article Number  \
# 0       6260783            70214  93118673            23101030601
# 1       6260784            70175  41446825            23100770000
# 2       6260785            72156  22740983            23101070000
# 3       6260786            72156  22740983            23101081101
# 4       6260786            72156  22740983            23101080001
#
#                                 Ordered Product Ordered Product - Supplement  \
# 0             Halteplatte für OPC-Schnittstelle         REOVIB [CODE] [CODE]
# 1           Gehäuse [CODE]/[NUM] [NUM], A [NUM]             Alu-/Gussgehäuse
# 2    Gehäuse kpl. [CODE] rf Z.Nr.:[CODE]-[CODE]                        [NUM]
# 3  Deckel Steuereinsatz [CODE],[CODE].[NUM] kpl                  Z.Nr:[CODE]
# 4     Gehäuse kpl. [CODE] Z.Nr.:KR519052_[PART]                        [NUM]
#
#    Original Ordered Quantity Original Desired Date Planned Delivery Date  \
# 0                       14.0            2023-05-01            2023-05-01
# 1                       50.0            2023-09-04            2023-09-04
# 2                       30.0            2023-08-21            2023-08-21
# 3                      100.0            2023-11-06            2023-11-06
# 4                      100.0            2023-11-06            2023-11-06
#
#    Ordered Quantity Arrival Date  Delivered Quantity  Delivery_Delay_Days  \
# 0              14.0   2023-05-23                14.0                   22
# 1              50.0   2023-09-04                50.0                    0
# 2              30.0   2023-08-24                30.0                    3
# 3             100.0   2023-11-03               100.0                   -3
# 4             100.0   2023-11-03               100.0                   -3
#
#     Status
# 0     late
# 1  on_time
# 2     late
# 3    early
# 4    early

# %%
# Company B: Feature-DataFrame

df_company_b_features = create_features_company_b(df_company_b_transformed)

print("Shape:", df_company_b_features.shape)
df_company_b_features.head()
# Out:
# Shape: (14896, 14)
#   Unique Order Identifier  Order Complexity  Supplier  \
# 0               6260783-1                 1  93118673
# 1               6260784-1                 1  41446825
# 2               6260785-1                 1  22740983
# 3               6260786-1                 4  22740983
# 4               6260786-2                 4  22740983
#
#   Unique Product Identifier Planned Delivery Date  Delivery Delay  \
# 0               23101030601            2023-05-01              22
# 1               23100770000            2023-09-04               0
# 2               23101070000            2023-08-21               3
# 3               23101081101            2023-11-06              -3
# 4               23101080001            2023-11-06              -3
#
#   Delivery Status  Ordered Quantity Arrival Date  Delivered Quantity  \
# 0        too late              14.0   2023-05-23                14.0
# 1         on time              50.0   2023-09-04                50.0
# 2        too late              30.0   2023-08-24                30.0
# 3       too early             100.0   2023-11-03               100.0
# 4       too early             100.0   2023-11-03               100.0
#
#    Delivery_Delay_Days   Status  Quantity Difference Quantity Status
# 0                   22     late                  0.0           exact
# 1                    0  on_time                  0.0           exact
# 2                    3     late                  0.0           exact
# 3                   -3    early                  0.0           exact
# 4                   -3    early                  0.0           exact

# %%
df_company_b_features.to_csv('df_company_b_features.csv', index=False)

# %%
df_company_b_encoded = create_date_encoded_features(df_company_b_features)

df_company_b_encoded.head()
# Out:
#   Unique Order Identifier  Order Complexity  Supplier  \
# 0               6260783-1                 1  93118673
# 1               6260784-1                 1  41446825
# 2               6260785-1                 1  22740983
# 3               6260786-1                 4  22740983
# 4               6260786-2                 4  22740983
#
#   Unique Product Identifier  Planned Year  Planned Month  Planned Quarter  \
# 0               23101030601          2023              5                2
# 1               23100770000          2023              9                3
# 2               23101070000          2023              8                3
# 3               23101081101          2023             11                4
# 4               23101080001          2023             11                4
#
#    Planned Day  Planned Weekday  Delivery Delay  ... Arrival Year  \
# 0            1                0              22  ...         2023
# 1            4                0               0  ...         2023
# 2           21                0               3  ...         2023
# 3            6                0              -3  ...         2023
# 4            6                0              -3  ...         2023
#
#    Arrival Month  Arrival Quarter  Arrival Day  Arrival Weekday  \
# 0              5                2           23                1
# 1              9                3            4                0
# 2              8                3           24                3
# 3             11                4            3                4
# 4             11                4            3                4
#
#    Delivered Quantity  Delivery_Delay_Days   Status  Quantity Difference  \
# 0                14.0                   22     late                  0.0
# 1                50.0                    0  on_time                  0.0
# 2                30.0                    3     late                  0.0
# 3               100.0                   -3    early                  0.0
# 4               100.0                   -3    early                  0.0
#
#   Quantity Status
# 0           exact
# 1           exact
# 2           exact
# 3           exact
# 4           exact
#
# [5 rows x 22 columns]

# %%
df_company_b_encoded.to_csv('company_b_ML.csv', index=False)

# %%
df_company_a_encoded.shape
# Out:
# (4459, 22)

# %%
df_company_b_encoded.shape
# Out:
# (14896, 22)
